# %%
import pandas as pd

# %%
data = {'coluna1': [1, 2, 3, 3, 4, 4],
        'coluna2': ['a', 'b', 'c', 'c', 'd', 'e']}

# %%
df = pd.DataFrame(data)
df
# Out:
#    coluna1 coluna2
# 0        1       a
# 1        2       b
# 2        3       c
# 3        3       c
# 4        4       d
# 5        4       e

# %%
df.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# 4    False
# 5    False
# dtype: bool

# %%
df.drop_duplicates()
# Out:
#    coluna1 coluna2
# 0        1       a
# 1        2       b
# 2        3       c
# 4        4       d
# 5        4       e

# %%
df.drop_duplicates(subset=['coluna1'],keep='last').sort_values(by='coluna1')
# Out:
#    coluna1 coluna2
# 0        1       a
# 1        2       b
# 3        3       c
# 5        4       e

# %% [markdown]
# ## exercício

# %% [markdown]
# eliminem as duplicatas do dataframe  em função da coluna valor e da coluna data, e digam a diferença.

# %%
dados={'valor':[18.3,10.1,14.32,17.52,16.31,81.14,17.52,16.31,81.14,18.3,10.1,14.32],'data': ['2022/01/01', '2022/01/02', '2022/01/03','2022/01/01', '2022/01/02', '2022/01/03','2022/01/01', '2022/01/02', '2022/01/03','2022/01/01', '2022/01/02', '2022/01/03'], 'entrada ou saída':['entrada','entrada','entrada','Saída','Saída','Saída','Saída','Saída','Saída','entrada','entrada','entrada']}

# %%
df = pd.DataFrame(dados)
df
# Out:
#     valor        data entrada ou saída
# 0   18.30  2022/01/01          entrada
# 1   10.10  2022/01/02          entrada
# 2   14.32  2022/01/03          entrada
# 3   17.52  2022/01/01            Saída
# 4   16.31  2022/01/02            Saída
# 5   81.14  2022/01/03            Saída
# 6   17.52  2022/01/01            Saída
# 7   16.31  2022/01/02            Saída
# 8   81.14  2022/01/03            Saída
# 9   18.30  2022/01/01          entrada
# 10  10.10  2022/01/02          entrada
# 11  14.32  2022/01/03          entrada

# %%
df.drop_duplicates().sort_values('valor',ascending=True)
# Out:
#    valor        data entrada ou saída
# 1  10.10  2022/01/02          entrada
# 2  14.32  2022/01/03          entrada
# 4  16.31  2022/01/02            Saída
# 3  17.52  2022/01/01            Saída
# 0  18.30  2022/01/01          entrada
# 5  81.14  2022/01/03            Saída

# %%
df.drop_duplicates(subset=['data']).sort_values('valor',ascending=True)
# Out:
#    valor        data entrada ou saída
# 1  10.10  2022/01/02          entrada
# 2  14.32  2022/01/03          entrada
# 0  18.30  2022/01/01          entrada

# %%
df.drop_duplicates(subset=['valor']).sort_values('valor',ascending=True)
# Out:
#    valor        data entrada ou saída
# 1  10.10  2022/01/02          entrada
# 2  14.32  2022/01/03          entrada
# 4  16.31  2022/01/02            Saída
# 3  17.52  2022/01/01            Saída
# 0  18.30  2022/01/01          entrada
# 5  81.14  2022/01/03            Saída

# %% [markdown]
# ## Datas

# %%
datas = {'data': ['2022-01-01', '2022-01-02', '2022-01-03']}

# %%
df = pd.DataFrame(datas)
df
# Out:
#          data
# 0  2022-01-01
# 1  2022-01-02
# 2  2022-01-03

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   data    3 non-null      object
# dtypes: object(1)
# memory usage: 152.0+ bytes

# %%
df['data']= pd.to_datetime(df.data)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   data    3 non-null      datetime64[ns]
# dtypes: datetime64[ns](1)
# memory usage: 152.0 bytes

# %%
df['ano'] = df.data.dt.year

# %%
df
# Out:
#         data   ano
# 0 2022-01-01  2022
# 1 2022-01-02  2022
# 2 2022-01-03  2022

# %%
df.mes = df.data.dt.month
# Out:
# /tmp/ipykernel_13557/2005551207.py:1: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   df.mes = df.data.dt.month

# %%
df
# Out:
#         data   ano
# 0 2022-01-01  2022
# 1 2022-01-02  2022
# 2 2022-01-03  2022

# %%
df['mes'] = df.data.dt.month
df['dia'] = df.data.dt.day
df['dia'] = df.data.dt.day_name()
df
# Out:
#         data   ano  mes       dia
# 0 2022-01-01  2022    1  Saturday
# 1 2022-01-02  2022    1    Sunday
# 2 2022-01-03  2022    1    Monday

# %%
df['prox_data'] = df['data'] +pd.DateOffset(days=7)

# %%
df
# Out:
#         data   ano  mes       dia  prox_data
# 0 2022-01-01  2022    1  Saturday 2022-01-08
# 1 2022-01-02  2022    1    Sunday 2022-01-09
# 2 2022-01-03  2022    1    Monday 2022-01-10

# %%
from datetime import timedelta

# %%
df.prox_data = df.data + timedelta(days=7)

# %%
df
# Out:
#         data   ano  mes       dia  prox_data
# 0 2022-01-01  2022    1  Saturday 2022-01-08
# 1 2022-01-02  2022    1    Sunday 2022-01-09
# 2 2022-01-03  2022    1    Monday 2022-01-10

# %%
datas_2 = {'data':['01/01/2022','02/01/2022','03/01/2022']}

# %%
df2 = pd.DataFrame(datas_2)

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   data    3 non-null      object
# dtypes: object(1)
# memory usage: 152.0+ bytes

# %%
df2['data'] = pd.to_datetime(df2.data,format='%d/%m/%Y')

# %%
df2
# Out:
#         data
# 0 2022-01-01
# 1 2022-01-02
# 2 2022-01-03

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   data    3 non-null      datetime64[ns]
# dtypes: datetime64[ns](1)
# memory usage: 152.0 bytes

# %% [markdown]
# Exercício: Para cada data no DataFrame, crie três novas colunas: uma para o mês, outra para o ano e outra para o dia.

# %%
data = {
    'datas': ['15/01/2024', '20/02/2024', '25/03/2024', '30/04/2024', '10/05/2024']
}

# %%
df = pd.DataFrame(data)

# %%
df['datas']= pd.to_datetime(df.datas,format='%d/%m/%Y')
df
# Out:
#        datas
# 0 2024-01-15
# 1 2024-02-20
# 2 2024-03-25
# 3 2024-04-30
# 4 2024-05-10

# %%
df['year'] = df.datas.dt.year
df['month'] = df.datas.dt.month
df['day'] = df.datas.dt.day

# %%
df
# Out:
#        datas  year  month  day
# 0 2024-01-15  2024      1   15
# 1 2024-02-20  2024      2   20
# 2 2024-03-25  2024      3   25
# 3 2024-04-30  2024      4   30
# 4 2024-05-10  2024      5   10

# %%
df['nome_do_mes']=df.datas.dt.strftime('%B')

# %%
df
# Out:
#        datas  year  month  day nome_do_mes
# 0 2024-01-15  2024      1   15     January
# 1 2024-02-20  2024      2   20    February
# 2 2024-03-25  2024      3   25       March
# 3 2024-04-30  2024      4   30       April
# 4 2024-05-10  2024      5   10         May

# %%
meses={1: 'janeiro', 2: 'fevereiro', 3: 'março', 4: 'abril',
         5: 'maio', 6: 'junho', 7: 'julho', 8: 'agosto',
         9: 'setembro', 10: 'outubro', 11: 'novembro', 12: 'dezembro'}

# %%
df['nome_do_mes'] = df.datas.dt.month.map(meses)
df
# Out:
#        datas  year  month  day nome_do_mes
# 0 2024-01-15  2024      1   15     janeiro
# 1 2024-02-20  2024      2   20   fevereiro
# 2 2024-03-25  2024      3   25       março
# 3 2024-04-30  2024      4   30       abril
# 4 2024-05-10  2024      5   10        maio

# %%
import locale

# %%
locale.setlocale(locale.LC_TIME,'pt_BR.UTF-8')
# Out:
# 'pt_BR.UTF-8'

# %%
df.nome_do_mes = df.datas.dt.month_name(locale='pt_BR.UTF-8')

# %%
df
# Out:
#        datas  year  month  day nome_do_mes
# 0 2024-01-15  2024      1   15     Janeiro
# 1 2024-02-20  2024      2   20   Fevereiro
# 2 2024-03-25  2024      3   25       Março
# 3 2024-04-30  2024      4   30       Abril
# 4 2024-05-10  2024      5   10        Maio

# %% [markdown]
# ## Amostras

# %%
data = {'coluna1': [1, 2, 3, 4, 5],
        'coluna2': ['a', 'b', 'c', 'd', 'e']}

# %%
df = pd.DataFrame(data)
df
# Out:
#    coluna1 coluna2
# 0        1       a
# 1        2       b
# 2        3       c
# 3        4       d
# 4        5       e

# %%
df.sample(n=3)
# Out:
#    coluna1 coluna2
# 4        5       e
# 1        2       b
# 0        1       a

# %%
fastfood = pd.read_excel('/home/arteweyl/coderhouse/python/turma-64010/datasets/fastfood.xlsx')

# %%
fastfood.shape
# Out:
# (515, 17)

# %%
fastfood.sample(n=200)
# Out:
#       restaurant                                       item  calories  \
# 258  Burger King                      Spicy Chicken Nuggets       530
# 514    Taco Bell                    Fiesta Taco Salad-Steak       720
# 122        Sonic  5 Piece Super Crunch Chicken Strip Dinner      1190
# 191        Arbys                          Super Greek Salad       720
# 423    Taco Bell                   Smothered Burrito - Beef       710
# ..           ...                                        ...       ...
# 367       Subway                      Footlong Veggie Patty       780
# 95         Sonic              Sonic Cheeseburger W/ Mustard       710
# 165        Arbys                            Roast Beef Gyro       550
# 240  Burger King                              Chicken Fries       290
# 96         Sonic              Sonic Cheeseburger W/ Ketchup       720
#
#      cal_fat  total_fat sat_fat            trans_fat  cholesterol  sodium  \
# 258      333         37       7                    0           55    1420
# 514      320         36       8                    1           55    1340
# 122      510         57      10                    1           90    2610
# 191      480         53      15                    0           85    1310
# 423      320         35      13                    1           75    2260
# ..       ...        ...     ...                  ...          ...     ...
# 367      140         14       2                    0           20    1600
# 95       380         43      17                    2          120    1120
# 165      260         29       7                    1           60    1290
# 240      150         17       3  2023-05-01 00:00:00           40     780
# 96       380         43      17                    2          120    1190
#
#      total_carb  fiber  sugar  protein  vit_a  vit_c  calcium  salad
# 258          28    NaN      0     20.0    NaN    NaN      NaN  Other
# 514          70    8.0      8     28.0    NaN    NaN      NaN  Other
# 122         126    8.0      9     44.0    2.0    8.0     14.0  Other
# 191          39    5.0      7     22.0    NaN    NaN      NaN  Other
# 423          70   10.0      4     28.0    NaN    NaN      NaN  Other
# ..          ...    ...    ...      ...    ...    ...      ...    ...
# 367         112   16.0     16     46.0   30.0   20.0     70.0  Other
# 95           43    2.0      7     35.0   10.0    8.0     30.0  Other
# 165          48    3.0      5     24.0   10.0   15.0     10.0  Other
# 240          18    1.0      1     16.0    NaN    NaN      NaN  Other
# 96           47    2.0     10     35.0   15.0   10.0     30.0  Other
#
# [200 rows x 17 columns]

# %%
df_amostra_1 = df.sample(n=3,random_state=42)

# %%
df_amostra_2 = df.sample(n=3,random_state=43)

# %%
pd.concat([df_amostra_1,df_amostra_2],ignore_index=True)
# Out:
#    coluna1 coluna2
# 0        2       b
# 1        5       e
# 2        3       c
# 3        4       d
# 4        3       c
# 5        2       b

# %%
fastfood_amostra_1=fastfood.sample(n=30,random_state=42)

# %%
fastfood_amostra_2=fastfood.sample(n=30,random_state=54)

# %%
fastfood_merge_amostras = pd.concat([fastfood_amostra_1,fastfood_amostra_2],ignore_index=True)

# %%
fastfood_merge_amostras
# Out:
#      restaurant                                               item  calories  \
# 0        Subway                                          6" B.L.T.       320
# 1     Taco Bell                                      Mexican Pizza       540
# 2     Taco Bell                    Spicy Sweet Double Stacked Taco       340
# 3         Arbys                                         Greek Gyro       710
# 4     Taco Bell                                    Steak Quesalupa       440
# 5         Sonic                         All Beef New York Dog – 6"       340
# 6   Burger King                            Extra Long Cheeseburger       580
# 7     Taco Bell                     Spicy Triple Double Crunchwrap       780
# 8        Subway                              6" Corned Beef Reuben       470
# 9   Burger King                                 Crispy Chicken Jr.       430
# 10    Taco Bell                                Fresco Crunchy Taco       140
# 11       Subway                                      Footlong Tuna       940
# 12  Dairy Queen                           Pork Tenderloin Sandwich       580
# 13        Sonic                     Hatch Green Chile Cheeseburger       710
# 14    Mcdonalds                                      Filet-O-Fish®       380
# 15       Subway                            Footlong Cold Cut Combo       740
# 16  Chick Fil-A                      Smokehouse BBQ Bacon Sandwich       500
# 17    Mcdonalds         Crispy Signature Sriracha Chicken Sandwich       730
# 18        Arbys                                       Pizza Slider       300
# 19  Burger King                          Bacon Cheeseburger Deluxe       290
# 20  Burger King  Bacon Cheddar Ranch Chicken Salad w/ grilled C...       590
# 21  Burger King                              Mushroom & Swiss King       940
# 22  Dairy Queen                              Chili Cheese Mega Dog       760
# 23  Burger King                             Jalapeno King Sandwich       990
# 24        Sonic                4 Piece Super Crunch Chicken Strips       440
# 25  Burger King                           Grilled Chili Cheese Dog       330
# 26  Chick Fil-A                 Spicy Grilled Chicken Sub Sandwich       430
# 27       Subway                         Oven Roasted Chicken Salad       140
# 28       Subway                                6" Steak and Cheese       380
# 29       Subway                                  6" Cold Cut Combo       370
# 30        Arbys                 Smokehouse Beef Short Rib Sandwich       590
# 31        Arbys                            Beef 'n Cheddar Classic       450
# 32  Chick Fil-A                                     Chick-n-Slider       270
# 33    Taco Bell                    Steak Spicy Cheesy Core Burrito       550
# 34        Sonic                  Large Spicy Jumbo Popcorn Chicken       610
# 35        Sonic   Garlic Parmesan Dunked Ultimate Chicken Sandwich      1350
# 36    Taco Bell                             Fiesta Taco Salad-Beef       780
# 37       Subway                                         Tuna Salad       310
# 38        Arbys                                         Greek Gyro       710
# 39       Subway                                  Subway Club Salad       140
# 40       Subway                                       B.L.T. Salad       150
# 41    Taco Bell                                  Chicken Quesalupa       440
# 42  Chick Fil-A                                       Spicy Deluxe       540
# 43    Taco Bell        Doritos® Cheesy Gordita Crunch - Cool Ranch       490
# 44    Taco Bell                              Beefy Mini Quesadilla       210
# 45        Sonic                           Veggie Burger W/ Ketchup       450
# 46        Arbys                             Buffalo Chicken Slider       290
# 47  Burger King                            Extra Long Cheeseburger       580
# 48    Mcdonalds           Grilled Sweet BBQ Bacon Chicken Sandwich       630
# 49        Sonic                4 Piece Super Crunch Chicken Strips       440
# 50    Mcdonalds                         40 piece Chicken McNuggets      1770
# 51  Dairy Queen                                  Breaded Mushrooms       250
# 52    Taco Bell                                 Black Bean Burrito       410
# 53    Mcdonalds          3 piece Buttermilk Crispy Chicken Tenders       370
# 54    Taco Bell      Doritos® Cheesy Gordita Crunch - Nacho Cheese       490
# 55    Taco Bell                   Beef Crunchy Cheesy Core Burrito       630
# 56       Subway                          6" Turkey & Bacon Avocado       390
# 57        Arbys                                   Greek Gyro Salad       420
# 58       Subway                             Black Forest Ham Salad       110
# 59    Taco Bell                         Gordita Supreme® - Chicken       270
#
#     cal_fat  total_fat              sat_fat            trans_fat  cholesterol  \
# 0        80          9                    4                    0           20
# 1       270         31                    8                    1           40
# 2       160         18                    7                    0           35
# 3       390         44                   13                    0           75
# 4       210         23                   10                  0.5           60
# 5       170         19                    7                    0           40
# 6       300         33                   13  2023-05-01 00:00:00           85
# 7       340         38                   10                  0.5           50
# 8       130         15  2023-05-04 00:00:00                    0           85
# 9       250         28  2023-05-04 00:00:00                    0           30
# 10       70          8                    2                    0           20
# 11      420         48                    8                    0           60
# 12      310         34                    7                    0           45
# 13      380         43                   17                    2          120
# 14      170         18                    4                    0           40
# 15      240         26                    8                    0          100
# 16      162         18                    0                    0           95
# 17      300         33                    7                    0           80
# 18      150         17                    6                    0           35
# 19      120         14                    6                  0.5           40
# 20      360         40                   12                    0          150
# 21      567         63                   21  2023-05-02 00:00:00          175
# 22      440         49                   21                    2          100
# 23      585         65                   24                    3          205
# 24      190         21                    4                    0           70
# 25      170         19                    8                    1           40
# 26      108         12  2023-05-04 00:00:00                    0           85
# 27       25          3                  0.5                    0           50
# 28       90         10                    5                    0           50
# 29      120         13                    4                    0           50
# 30      250         59                   10                    1           75
# 31      180         20                    6                    1           50
# 32       99         11  2023-05-02 00:00:00                    0           45
# 33      190         21                    9                    0           50
# 34      270         30                    5                    0           80
# 35      900        100                   17                    0          190
# 36      380         42                   10                    1           60
# 37      215         24                    4                    0           40
# 38      390         44                   13                    0           75
# 39       30          4                    1                    0           40
# 40       70          8                    4                    0           20
# 41      200         23                   10                  0.5           60
# 42      225         25                    8                    0           80
# 43      250         28                   10                    1           55
# 44      110         12                    4                    0           25
# 45      130         14                    4                    0           10
# 46      120         13                    2                    0           20
# 47      300         33                   13  2023-05-01 00:00:00           85
# 48      200         22                    7                    0          135
# 49      190         21                    4                    0           70
# 50      960        107                   18                  0.5          295
# 51       80          9                    1                    0            0
# 52      110         12                    4                    0           10
# 53      190         21  2023-05-03 00:00:00                    0           70
# 54      250         28                   10                    1           55
# 55      240         26                   10                  0.5           45
# 56      110         13  2023-05-03 00:00:00                    0           30
# 57      340         37                    9                    0           55
# 58       25          3                    1                    0           20
# 59       90         10                    4                    0           40
#
#     sodium  total_carb  fiber  sugar  protein  vit_a  vit_c  calcium  salad
# 0      680          43    5.0      6     15.0    8.0    8.0     30.0  Other
# 1      860          47    7.0      2     20.0    NaN    NaN      NaN  Other
# 2      640          32    4.0      6     12.0   10.0    2.0     15.0  Other
# 3     1360          55    4.0      6     23.0    NaN    NaN      NaN  Other
# 4      840          36    3.0      3     22.0   15.0    6.0     35.0  Other
# 5     1250          30    3.0      4     13.0    2.0   10.0      8.0  Other
# 6     1030          45    2.0      9     26.0    NaN    NaN      NaN  Other
# 7     1850          87    9.0      8     23.0   20.0   10.0     25.0  Other
# 8     1770          45    7.0     12     39.0   10.0   35.0     20.0  Other
# 9      760          34    2.0      4     12.0    NaN    NaN      NaN  Other
# 10     290          13    3.0      1      6.0    NaN    NaN      NaN  Other
# 11    1240          88   10.0     12     40.0   16.0   40.0     60.0  Other
# 12     910          48    2.0      6     19.0    NaN    NaN      NaN  Other
# 13    1120          44    2.0      7     35.0   10.0   25.0     30.0  Other
# 14     640          38    2.0      5     15.0    2.0    0.0     15.0  Other
# 15    2280          92   10.0     14     36.0   20.0   40.0     70.0  Other
# 16    1200          46    2.0     10     33.0   45.0   40.0     20.0  Other
# 17    1430          75    5.0     13     32.0   20.0   20.0     30.0  Other
# 18     930          23    1.0      2     13.0    NaN    NaN      NaN  Other
# 19     720          28    1.0      7     12.0    NaN    NaN      NaN  Other
# 20    1540          18    3.0      6     42.0    NaN    NaN      NaN  Other
# 21    1380          45    NaN      8     49.0    NaN    NaN      NaN  Other
# 22    1570          48    2.0      6     32.0    NaN    NaN      NaN  Other
# 23    1550          46    2.0      7     55.0    NaN    NaN      NaN  Other
# 24     900          34    2.0      1     29.0    1.0    2.0      1.0  Other
# 25     980          28    2.0      5     14.0    NaN    NaN      NaN  Other
# 26    1310          47    5.0      9     33.0    NaN   25.0     25.0  Other
# 27     280          10    4.0      4     19.0   50.0   60.0      8.0  Other
# 28    1060          48    5.0      8     26.0   10.0   20.0     40.0  Other
# 29    1140          46    5.0      7     18.0   10.0   20.0     35.0  Other
# 30    1510          59    4.0     14     26.0    NaN    NaN      NaN  Other
# 31    1280          45    2.0      9     23.0    2.0    2.0     15.0  Other
# 32     800          26    1.0      4     16.0    NaN    0.0      2.0  Other
# 33    1750          66    5.0      5     24.0   10.0    6.0     35.0  Other
# 34    1500          51    3.0      0     36.0   17.0    0.0      3.0  Other
# 35    2180          69    4.0     10     23.0    NaN    NaN      NaN  Other
# 36    1340          74   11.0      7     26.0    NaN    NaN      NaN  Other
# 37     370          10    4.0      4     15.0   50.0   50.0      6.0  Other
# 38    1360          55    4.0      6     23.0    NaN    NaN      NaN  Other
# 39     640          11    4.0      5     17.0   25.0   45.0      6.0  Other
# 40     420          10    4.0      5     10.0   50.0   50.0      6.0  Other
# 41     840          37    3.0      3     22.0   15.0    8.0     35.0  Other
# 42    1760          43    2.0      6     34.0   30.0   10.0     30.0  Other
# 43     890          40    5.0      5     20.0    NaN    NaN      NaN  Other
# 44     560          17    3.0      1      9.0    NaN    NaN      NaN  Other
# 45    1410          67    5.0     11     15.0    6.0    8.0     25.0  Other
# 46     860          31    2.0      2     12.0    NaN    NaN      NaN  Other
# 47    1030          45    2.0      9     26.0    NaN    NaN      NaN  Other
# 48    1930          61    4.0     18     48.0    4.0   30.0     25.0  Other
# 49     900          34    2.0      1     29.0    1.0    2.0      1.0  Other
# 50    3370         105    7.0      1     98.0    0.0   15.0      6.0  Other
# 51     500          36    2.0      1      7.0    0.0    2.0      2.0  Other
# 52    1100          62    8.0      3     14.0    NaN    NaN      NaN  Other
# 53     910          16    0.0      0     28.0    0.0    0.0      2.0  Other
# 54     880          40    5.0      5     20.0    NaN    NaN      NaN  Other
# 55    1530          76    7.0      5     22.0   15.0    4.0     35.0  Other
# 56     860          49    8.0      7     22.0   10.0  200.0     30.0  Other
# 57     700          11    2.0      4     10.0    NaN    NaN      NaN  Other
# 58     590          11    4.0      6     12.0   25.0   45.0      4.0  Other
# 59     510          29    2.0      6     16.0    NaN    NaN      NaN  Other

# %% [markdown]
# Utilizando a base "realtor-data.csv" gerar uma amostra com os seguintes requisitos:
#
# amostra aleatória
# com 1.000 registros, sendo:
# 250 do estado de Massachusetts
# 250 do estado de Puerto Rico
# 250 do estado de Connecticut
# 250 dos estados Rhode Island e New York
# somente casas for_sale
# sem duplicidades de status, city, state e price
# na remoção de duplicados priorizar as casas maiores.
# Valide a amostra criada.

# %%
realtor = pd.read_csv('/home/arteweyl/coderhouse/python/turma-64010/datasets/realtor-data.csv')
realtor.head(3)
# Out:
#      status  bed  bath  acre_lot        city        state  zip_code  \
# 0  for_sale  3.0   2.0      0.12    Adjuntas  Puerto Rico     601.0
# 1  for_sale  4.0   2.0      0.08    Adjuntas  Puerto Rico     601.0
# 2  for_sale  2.0   1.0      0.15  Juana Diaz  Puerto Rico     795.0
#
#    house_size prev_sold_date     price
# 0       920.0            NaN  105000.0
# 1      1527.0            NaN   80000.0
# 2       748.0            NaN   67000.0

# %%
realtor.shape
# Out:
# (100000, 10)

# %%
realtor.groupby('status').count()[['price']]
# Out:
#                 price
# status
# for_sale        99819
# ready_to_build    181

# %%
realtor.groupby('state').count()['price'].sort_values(ascending=False)
# Out:
# state
# Massachusetts     52694
# Puerto Rico       24679
# Connecticut       12178
# Virgin Islands     2573
# Rhode Island       2401
# New Hampshire      2232
# New York           1874
# Vermont            1324
# South Carolina       24
# Tennessee            16
# Virginia              3
# New Jersey            2
# Name: price, dtype: int64

# %%
realtor_fs=realtor[realtor.status == 'for_sale']
realtor_fs.shape
# Out:
# (99819, 10)

# %%
realtor_fs = realtor_fs.sort_values('house_size')

# %%
realtor_dup = realtor_fs.drop_duplicates(['status','city','state','price'],keep='last')

# %%
realtor_dup.shape
# Out:
# (12067, 10)

# %%
massachusetts=realtor_dup[realtor_dup.state == 'Massachusetts']
puerto_rico=realtor_dup[realtor_dup.state == 'Puerto Rico']
connecticut = realtor_dup[realtor_dup.state == 'Connecticut']
rhode_island_new_york = realtor_dup[realtor_dup.state.isin(['Rhode Island','New York'])]

print(massachusetts.shape)
print(puerto_rico.shape)
print(connecticut.shape)
print(rhode_island_new_york.shape)
# Out:
# (3349, 10)
# (2207, 10)
# (3111, 10)
# (2149, 10)

# %%
massachusetts_sample = massachusetts.sample(n=250,random_state=42)
puerto_rico_sample = puerto_rico.sample(n=250,random_state=42)
connecticut_sample = connecticut.sample(n=250,random_state=42)
rhode_island_new_york_sample = rhode_island_new_york.sample(n=250,random_state=42)

# %%
sample = pd.concat([massachusetts_sample,puerto_rico_sample,connecticut_sample,rhode_island_new_york_sample],ignore_index=True)
sample.shape
# Out:
# (1000, 10)

# %%
sample.head(10)
# Out:
#      status   bed  bath  acre_lot              city          state  zip_code  \
# 0  for_sale   4.0   4.0      0.97   East Longmeadow  Massachusetts    1028.0
# 1  for_sale   NaN   NaN      2.80              Otis  Massachusetts    1253.0
# 2  for_sale   2.0   3.0       NaN         Hopkinton  Massachusetts    1748.0
# 3  for_sale   3.0   3.0      0.30  Great Barrington  Massachusetts    1230.0
# 4  for_sale   NaN   NaN      2.00       Phillipston  Massachusetts    1331.0
# 5  for_sale   5.0   2.0      1.00         Leicester  Massachusetts    1524.0
# 6  for_sale  11.0   6.0     85.00         Sheffield  Massachusetts    1257.0
# 7  for_sale   NaN   NaN      0.29             Adams  Massachusetts    1220.0
# 8  for_sale   3.0   3.0      0.34            Palmer  Massachusetts    1069.0
# 9  for_sale   3.0   2.0      0.33        Leominster  Massachusetts    1453.0
#
#    house_size prev_sold_date       price
# 0      3000.0     2006-09-28    739900.0
# 1         NaN            NaN     47500.0
# 2      2463.0            NaN    979900.0
# 3      2054.0            NaN    769000.0
# 4         NaN            NaN     45000.0
# 5      1624.0            NaN    399900.0
# 6      5850.0            NaN  11890000.0
# 7         NaN            NaN     42000.0
# 8      3390.0     2002-01-25    480000.0
# 9      1434.0            NaN    369000.0
