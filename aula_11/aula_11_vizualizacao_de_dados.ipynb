# %%
# %pip install matplotlib
# %pip install seaborn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
x = [1,2,4,8,16]
y = [8,6,4,2,1]

# %% [markdown]
# ### plot

# %%
plt.plot(x,y)
plt.show()

# %%
plt.scatter(x,y)
plt.show()

# %%
frutas = ['banana','pera','uva','mamao']
quantidade = [3,5,9,10]

plt.bar(frutas,quantidade)
plt.show()

# %%
cidades = ['são paulo','belém','fortaleza']
populacao = [12,4,2]

plt.pie(populacao,labels=cidades,autopct='%1.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x7f2d7f0fc450>,
# ...
#  [Text(-0.5500000594609755, 0.9526279098330699, 'são paulo'),
#   Text(0.1910131363013876, -1.083288503474632, 'belém'),
#   Text(1.0336619347227232, -0.3762220151789061, 'fortaleza')],
#  [Text(-0.30000003243325934, 0.5196152235453108, '66.7%'),
#   Text(0.1041889834371205, -0.59088463825889, '22.2%'),
#   Text(0.563815600757849, -0.20521200827940328, '11.1%')])

# %%
dados = [1, 3, 3, 4, 4, 4, 5, 5, 6, 7, 8, 9]
plt.hist(dados,bins=4)
plt.show()

# %%
meses = ['Jan', 'Fev', 'Mar', 'Abr', 'Mai', 'Jun']
dorama_a = [120, 135, 150, 180, 200, 230]
dorama_b = [80, 85, 90, 100, 110, 125]
dorama_c = [100, 115, 130, 145, 160, 190]

# %%
plt.plot(meses,dorama_a,label='Dorama A')
plt.xlabel('meses')
plt.ylabel('Popularidade')
plt.title('A popularidade de doramas só tende a crescer em 2024')
plt.plot(meses,dorama_b,label='Dorama B')
plt.plot(meses,dorama_c,label='Dorama C')
plt.legend()
plt.show()

# %%
plt.plot(meses,dorama_a,color='red',label='Dorama A')
plt.xlabel('meses')
plt.ylabel('Popularidade')
plt.title('A popularidade de doramas só tende a crescer')
plt.plot(meses,dorama_b,label='Dorama B',color='gray',linestyle='dashdot')
plt.plot(meses,dorama_c,label='Dorama C',color='gray',linestyle='--', marker='o',markersize=5,markerfacecolor='gray')
plt.legend()
plt.show()

# %%
import numpy as np

# %%
t = np.linspace(0,10,100)
x = np.sin(t)
y = np.cos(t)

plt.plot(t,x,label='Seno de t',color='blue')
plt.plot(t,y,label='Seno de t',color='red')
plt.legend()
plt.show()

# %%
t = np.linspace(0,10,100)
x = np.sin(t)
y = np.cos(t)
z = np.tan(t)

plt.plot(t,x,label='Seno de t',color='blue')
plt.plot(t,y,label='Cosseno de t',color='red')
plt.plot(t,z,label='Tangente de t',color='orange')
plt.legend()
plt.show()

# %%
idade = [18,20,30,40,60]
salario = [1000,2000,3000,4000,5000]

# %%
df = pd.DataFrame({'idade':idade,'salario': salario})
sns.scatterplot(x = 'idade',y = 'salario',data = df,alpha = 0.5)
# Out:
# <Axes: xlabel='idade', ylabel='salario'>

# %%
x = [1, 2, 3, 4, 5]
y = [2, 4, 6, 8, 10]
plt.fill_between(x,y)
plt.show()

# %%
generos = ['misterio', 'fantasia', 'comedia', 'romance', 'drama']
quantidade_doramas = [15, 20, 25, 30, 22]

fig, ax = plt.subplots()

cores = ['gray']*len(quantidade)

cores[generos.index('romance')] = 'red'

barras = ax.bar(generos,quantidade_doramas,color=cores)


# Adicionando títulos e rótulos
ax.set_title('love is in the air')
ax.set_xlabel('Ano')
ax.set_ylabel('Quantidade de Doramas')

plt.show()

# %%
tokusatsu = ['jaspion','jiraya','black kamen rider']
paises = ['coreia do sul','japão','brasil','EUA','china']

popularidade = np.array(
    [
        [80,70,50,40,30],
        [50,60,70,80,90],
        [90,80,70,60,50]
    ])

# %%
df = pd.DataFrame(popularidade,columns=paises,index=tokusatsu)
df
# Out:
#                    coreia do sul  japão  brasil  EUA  china
# jaspion                       80     70      50   40     30
# jiraya                        50     60      70   80     90
# black kamen rider             90     80      70   60     50

# %%
plt.figure(figsize=(10,6))
sns.heatmap(popularidade,xticklabels=paises,yticklabels=tokusatsu,cmap='Blues')
plt.show()

# %%
np.random.seed(42)
num_episodios= np.random.randint(10,50,100)
avaliacoes = np.random.normal(8,0.5,100)

# %%
plt.scatter(num_episodios,avaliacoes)
plt.show()

# %%
plt.hexbin(num_episodios,avaliacoes,gridsize=20,cmap='Blues')

# %%
dados = {
    'Gênero': ['Romance', 'Comédia', 'Drama', 'Fantasia', 'Mistério'] * 20,
    'Avaliação': np.random.normal(8, 0.5, 100)
}

df = pd.DataFrame(dados)

df
# Out:
#       Gênero  Avaliação
# 0    Romance   8.113144
# 1    Comédia   8.423701
# 2      Drama   8.087417
# 3   Fantasia   7.391573
# 4   Mistério   8.524674
# ..       ...        ...
# 95   Romance   8.633203
# 96   Comédia   8.188648
# 97     Drama   8.825675
# 98  Fantasia   7.336584
# 99  Mistério   8.921858
#
# [100 rows x 2 columns]

# %%
plt.figure(figsize=(8,6))
sns.boxplot(x='Gênero',y='Avaliação',data=df)
plt.title('Distribuição de Avaliações por Gênero')
plt.xlabel('Gênero')
plt.ylabel('Avaliação')
plt.show()

# %%
fig,axs  = plt.subplots(2,2,figsize=(10,10))
#gráfico 1 hexbin
axs[0,0].hexbin(num_episodios,avaliacoes,gridsize=20,cmap='Blues')
axs[0,0].set_title('Distribuição de Avaliações')
axs[0,0].set_xlabel('Número de Episódios')
axs[0,0].set_ylabel('Avaliações')

#gráfico 2 boxplot
sns.boxplot(x='Gênero',y='Avaliação',data=df,ax=axs[0,1])
axs[0, 1].set_title('Boxplot: Avaliações por Gênero')

#gráfico 3: displot
sns.histplot(avaliacoes,kde=True,ax=axs[1,0])
axs[1,0].set_title('Histograma: Distribuição de Avaliações')
axs[1,0].set_xlabel('Avaliações')

#gráfico 4: gráfico de barras
anos = ['2018', '2019', '2020', '2021', '2022']
quantidade_doramas = [15, 20, 25, 30, 22]
axs[1,1].bar(anos,quantidade_doramas,color='teal')
axs[1,1].set_title('Quantidade de Doramas por Ano')
axs[1,1].set_xlabel('Ano')
axs[1,1].set_ylabel('Quantidade de Doramas')

plt.show()
