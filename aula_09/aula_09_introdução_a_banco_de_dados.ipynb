# %%
import pandas as pd
import sqlite3

# %%
produtos = {'nome':('ovos','manteiga','peixe'),'valor':(10,20,30)}

# %%
print(produtos)
# Out:
# {'nome': ('ovos', 'manteiga', 'peixe'), 'valor': (10, 20, 30)}

# %%
print(produtos['valor'])
# Out:
# (10, 20, 30)

# %%
df_produtos = pd.DataFrame(produtos)
df_produtos
# Out:
#        nome  valor
# 0      ovos     10
# 1  manteiga     20
# 2     peixe     30

# %%
df_produtos.to_csv('produtos.csv',index=False)

# %%
conn= sqlite3.connect('coderhouse.db')

# %%
df_produtos.to_sql('produtos',conn,if_exists='replace',index=False)
# Out:
# 3

# %% [markdown]
# df.to_sql(TABELA,CONEXÃO,o que fazer com a tabela, e como lidar com os indíces)

# %%
conn.close()

# %%
conn = sqlite3.connect('coderhouse.db')
query ='SELECT nome from produtos'
df = pd.read_sql(query,conn)
df
# Out:
#        nome
# 0      ovos
# 1  manteiga
# 2     peixe

# %%
query ="""SELECT nome
          FROM produtos 
          WHERE nome= 'manteiga'"""
df = pd.read_sql(query,conn)
df
# Out:
#        nome
# 0  manteiga

# %%
conn.close()

# %%
conn = sqlite3.connect('coder.db')
query = 'SELECT * FROM dragon_ball'
dragonball = pd.read_sql(query,conn)
dragonball
# Out:
#    ID CHARACTER_NAME      SPECIES  POWER_LEVEL FIRST_APPEARANCE
# 0   1           Goku       Saiyan         9001       1984-12-03
# 1   2         Vegeta       Saiyan         9000       1989-04-26
# 2   3        Piccolo     Namekian         5000       1988-06-22
# 3   4          Gohan  Half-Saiyan         2500       1989-04-26
# 4   5         Frieza  Frieza Race          530       1990-02-26
# 5   6           Cell  Bio-Android          850       1992-02-16
# 6   7      Majin Buu        Majin         1000       1994-02-09
# 7   8        Krillin        Human          100       1984-12-03
# 8   9         Trunks  Half-Saiyan         2000       1991-04-26
# 9  10          Goten  Half-Saiyan         1500       1992-02-26

# %%
query = "SELECT name FROM sqlite_master WHERE type='table'"
dragonbal=pd.read_sql_query(query,conn)

# %%
from util_db import salva_no_bd, carrega_do_db,mostra_tabelas_bd

# %%
salva_no_bd(dragonball,'dragon_ball','coderhouse.db')
# Out:
# True

# %%
conn=sqlite3.connect('coderhouse.db')
novo_df = pd.read_sql("SELECT * from dragon_ball",conn)
novo_df
# Out:
#    ID CHARACTER_NAME      SPECIES  POWER_LEVEL FIRST_APPEARANCE
# 0   1           Goku       Saiyan         9001       1984-12-03
# 1   2         Vegeta       Saiyan         9000       1989-04-26
# 2   3        Piccolo     Namekian         5000       1988-06-22
# 3   4          Gohan  Half-Saiyan         2500       1989-04-26
# 4   5         Frieza  Frieza Race          530       1990-02-26
# 5   6           Cell  Bio-Android          850       1992-02-16
# 6   7      Majin Buu        Majin         1000       1994-02-09
# 7   8        Krillin        Human          100       1984-12-03
# 8   9         Trunks  Half-Saiyan         2000       1991-04-26
# 9  10          Goten  Half-Saiyan         1500       1992-02-26

# %%
dragonball_2 =carrega_do_db('dragon_ball', 'coderhouse.db')

# %%
dragonball_2
# Out:
#    ID CHARACTER_NAME      SPECIES  POWER_LEVEL FIRST_APPEARANCE
# 0   1           Goku       Saiyan         9001       1984-12-03
# 1   2         Vegeta       Saiyan         9000       1989-04-26
# 2   3        Piccolo     Namekian         5000       1988-06-22
# 3   4          Gohan  Half-Saiyan         2500       1989-04-26
# 4   5         Frieza  Frieza Race          530       1990-02-26
# 5   6           Cell  Bio-Android          850       1992-02-16
# 6   7      Majin Buu        Majin         1000       1994-02-09
# 7   8        Krillin        Human          100       1984-12-03
# 8   9         Trunks  Half-Saiyan         2000       1991-04-26
# 9  10          Goten  Half-Saiyan         1500       1992-02-26

# %%
mostra_tabelas_bd('coderhouse.db')
# Out:
#           name
# 0     produtos
# 1  dragon_ball

# %%
# %pip install psycopg2-binary
# %pip install sqlalchemy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 3.5 MB/s eta 0:00:0000:0100:010m
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 602.4/602.4 KB 3.7 MB/s eta 0:00:0000:0100:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from sqlalchemy import create_engine
import pandas as pd

# %%
conn = create_engine('postgresql+psycopg2://root:root@localhost:5432/test_db').connect()

# %%
pd.read_sql('select * from personagens',conn)
# Out:
#     index                  Nome Primeira Aparição   Tipo de Poder Alinhamento  \
# 0       0          Homem-Aranha              1962       Agilidade       Herói
# 1       1        Homem de Ferro              1963      Tecnologia       Herói
# 2       2       Capitão América              1941           Força       Herói
# 3       3                  Thor              1962            Deus       Herói
# 4       4                  Hulk              1962           Força       Herói
# 5       5           Viúva Negra              1964      Espionagem       Herói
# 6       6       Doutor Estranho              1963           Magia       Herói
# 7       7  Feiticeira Escarlate              1964           Magia       Herói
# 8       8         Pantera Negra              1966           Força       Herói
# 9       9         Capitã Marvel              1968         Energia       Herói
# 10     10             Wolverine              1974     Regeneração       Herói
# ...
